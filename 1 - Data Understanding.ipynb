# %% [markdown]
# # Data Understanding

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from IPython.display import display

# %% [markdown]
# The analyzed dataset consists of 2452 records, each described by 38 attributes. Three variables (actor, vocal_channel, intensity) have missing values. As we will see later, the variable 'actor' has a large number of missing values and for this reason we decided to remove it from the dataset. For the other two variables, however, we decided to fill them. 'Intensity' will be filled by a linear regression application, while vocal_channel will be filled randomly taking into consideration the frequency proportions in the dataset. After printing the values of the attributes, we noticed the presence of four variables with a single value (modality, sample_width, frame_rate, stft_max) and we decided, therefore, to remove them from the dataset as they did not contribute with additional information. In addition, frame_count and length_ms are two perfectly correlated variables, so we decided to remove frame_count as the information in the dataset would have been redundant. In addition we dropped all those columns that have a std <0.1 because they dont give a sufficient variety to the values and this application can be useful for us while we will do the cluster analysis and classification. The features that we obtained with cleaned dataset are: 'vocal_channel', 'emotion', 'emotional_intensity', 'repetition', 'sex', 'length_ms', 'intensity', 'zero_crossings_sum', 'mfcc_mean', 'mfcc_std','mfcc_min', 'mfcc_max', 'sc_mean', 'sc_std', 'sc_min', 'sc_max', 'sc_kur', 'sc_skew', 'stft_kur', 'stft_skew', 'max', 'kur', 'skew', 'angry', 'calm', 'disgust', 'fearful', 'happy', 'neutral', 'sad', 'surprised'.

# %%
df = pd.read_csv('ravdess_features.csv', skip_blank_lines=True)
df.head()
# Out:
#      modality vocal_channel    emotion emotional_intensity  \
# 0  audio-only        speech    fearful              normal
# 1  audio-only        speech      angry              normal
# 2  audio-only           NaN      happy              strong
# 3  audio-only           NaN  surprised              normal
# 4  audio-only          song      happy              strong
#
#                       statement repetition  actor sex  channels  sample_width  \
# 0  Dogs are sitting by the door        2nd    2.0   F         1             2
# 1  Dogs are sitting by the door        1st   16.0   F         1             2
# 2  Dogs are sitting by the door        2nd   16.0   F         1             2
# 3  Kids are talking by the door        1st   14.0   F         1             2
# 4  Dogs are sitting by the door        2nd    2.0   F         1             2
#
#    frame_rate  frame_width  length_ms  frame_count  intensity  \
# 0       48000            2       3737     179379.0 -36.793432
# 1       48000            2       3904     187387.0        NaN
# 2       48000            2       4671     224224.0 -32.290737
# 3       48000            2       3637     174575.0 -49.019839
# 4       48000            2       4404     211411.0 -31.214503
#
#    zero_crossings_sum  mfcc_mean    mfcc_std   mfcc_min   mfcc_max  \
# 0               16995 -33.485947  134.654860 -755.22345  171.69092
# 1               13906 -29.502108  130.485630 -713.98560  205.00770
# 2               18723 -30.532463  126.577110 -726.06036  165.45653
# 3               11617 -36.059555  159.725160 -842.94635  190.03609
# 4               15137 -31.405996  122.125824 -700.70276  161.13400
#
#        sc_mean       sc_std  sc_min        sc_max    sc_kur   sc_skew  \
# 0  5792.550744  3328.055457     0.0  13541.959028 -1.120769  0.250940
# 1  5197.620555  4040.931570     0.0  12000.290443 -1.531204  0.219582
# 2  4830.743037  3332.131300     0.0  12007.751173 -1.130153  0.436699
# 3  5376.446478  4053.663073     0.0  12048.223893 -1.497765  0.098802
# 4  5146.012474  3442.724109     0.0  12025.582707 -1.167544  0.496066
#
#    stft_mean  stft_std  stft_min  stft_max  stft_kur  stft_skew          mean  \
# 0   0.415250  0.335533       0.0       1.0 -1.215025   0.403514  3.844916e-07
# 1   0.417488  0.352380       0.0       1.0 -1.384174   0.290905 -7.149491e-08
# 2   0.379758  0.352270       0.0       1.0 -1.242947   0.470350  2.429985e-06
# 3   0.407277  0.360552       0.0       1.0 -1.445318   0.274756  2.373929e-07
# 4   0.415974  0.350655       0.0       1.0 -1.366742   0.318926  8.454691e-07
#
#         std       min       max        kur      skew
# 0  0.014482 -0.128632  0.138947   9.406061  0.273153
# 1  0.020417 -0.305725  0.263062  19.564187  0.292157
# 2  0.024317 -0.137482  0.166351   4.881241  0.302659
# 3  0.003561 -0.027374  0.024078  13.040259 -0.081014
# 4  0.027522 -0.192169  0.242676   7.485109  0.414872

# %%
#Visualization of descriptive statistics
df.describe()
# Out:
#              actor     channels  sample_width  frame_rate  frame_width  \
# count  1326.000000  2452.000000        2452.0      2452.0  2452.000000
# mean     12.582202     1.002447           2.0     48000.0     2.004894
# std       6.916240     0.049416           0.0         0.0     0.098833
# min       1.000000     1.000000           2.0     48000.0     2.000000
# 25%       7.000000     1.000000           2.0     48000.0     2.000000
# 50%      13.000000     1.000000           2.0     48000.0     2.000000
# 75%      19.000000     1.000000           2.0     48000.0     2.000000
# max      24.000000     2.000000           2.0     48000.0     4.000000
#
#          length_ms    frame_count    intensity  zero_crossings_sum  \
# count  2452.000000    2452.000000  1636.000000         2452.000000
# mean   4092.151305  193587.188010   -37.625332        12885.314029
# std     598.321526   36825.369056     8.451982         3665.319584
# min    2936.000000      -1.000000   -63.864613         4721.000000
# 25%    3604.000000  172972.000000   -43.539869        10362.500000
# 50%    4004.000000  190591.000000   -37.072745        12383.500000
# 75%    4538.000000  217817.000000   -31.591309        14966.000000
# max    6373.000000  305906.000000   -16.353953        30153.000000
#
#          mfcc_mean     mfcc_std     mfcc_min     mfcc_max      sc_mean  \
# count  2452.000000  2452.000000  2452.000000  2452.000000  2452.000000
# mean    -28.769180   136.777233  -758.909381   199.182514  5170.101398
# std       4.461886    20.451689    99.945452    26.002107   875.185444
# min     -43.812923    83.621370 -1085.479700   126.250810  2360.880942
# 25%     -31.828597   122.623928  -826.464075   180.081417  4563.684781
# 50%     -28.681109   136.523810  -760.983065   201.697175  5122.712259
# 75%     -25.550238   151.385135  -692.890015   218.185288  5775.959809
# max     -15.491450   195.942920  -461.489320   280.173700  7655.335726
#
#             sc_std       sc_min        sc_max       sc_kur      sc_skew  \
# count  2452.000000  2452.000000   2452.000000  2452.000000  2452.000000
# mean   3365.453393   551.834124  11830.461864    -1.142642     0.348442
# std     580.479034   508.025890   1004.955976     0.572654     0.353005
# min    1491.341071     0.000000   7657.495158    -1.795576    -0.510390
# 25%    3025.431971     0.000000  11516.034429    -1.496187     0.098549
# 50%    3433.835368   707.319256  12000.292653    -1.308938     0.347621
# 75%    3768.503344   977.693852  12091.886054    -0.982944     0.557427
# max    4819.783069  2121.417965  17477.540047     3.657953     1.825436
#
#          stft_mean     stft_std     stft_min  stft_max     stft_kur  \
# count  2452.000000  2452.000000  2452.000000    2452.0  2452.000000
# mean      0.475846     0.331371     0.002272       1.0    -1.247929
# std       0.082551     0.023773     0.004830       0.0     0.211781
# min       0.214089     0.210126     0.000000       1.0    -1.669603
# 25%       0.415260     0.317780     0.000000       1.0    -1.390612
# 50%       0.475740     0.334224     0.000190       1.0    -1.292105
# 75%       0.530571     0.349272     0.001999       1.0    -1.152519
# max       0.724077     0.391928     0.039378       1.0     0.794669
#
#          stft_skew          mean          std          min          max  \
# count  2452.000000  2.452000e+03  2452.000000  2452.000000  2452.000000
# mean      0.112889  1.393649e-08     0.020504    -0.164871     0.179839
# std       0.330759  4.267587e-05     0.021024     0.175443     0.195539
# min      -0.993957 -9.435575e-04     0.000652    -0.998810     0.004669
# 25%      -0.094334 -1.394488e-06     0.006791    -0.202431     0.055489
# 50%       0.126065 -9.810701e-08     0.013880    -0.103775     0.109726
# 75%       0.335574  8.363511e-07     0.026154    -0.054352     0.224487
# max       1.465815  1.222810e-03     0.152168    -0.006134     0.999146
#
#                kur         skew
# count  2452.000000  2452.000000
# mean     11.203002    -0.048245
# std       6.614859     0.454925
# min       1.757794    -2.356526
# 25%       6.519988    -0.336624
# 50%       9.828686     0.004256
# 75%      14.085435     0.262978
# max      59.085695     1.799676

# %%
#Printing information about a the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452 entries, 0 to 2451
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   modality             2452 non-null   object
#  1   vocal_channel        2256 non-null   object
#  2   emotion              2452 non-null   object
#  3   emotional_intensity  2452 non-null   object
#  4   statement            2452 non-null   object
#  5   repetition           2452 non-null   object
#  6   actor                1326 non-null   float64
#  7   sex                  2452 non-null   object
#  8   channels             2452 non-null   int64
#  9   sample_width         2452 non-null   int64
#  10  frame_rate           2452 non-null   int64
#  11  frame_width          2452 non-null   int64
#  12  length_ms            2452 non-null   int64
#  13  frame_count          2452 non-null   float64
#  14  intensity            1636 non-null   float64
#  15  zero_crossings_sum   2452 non-null   int64
#  16  mfcc_mean            2452 non-null   float64
#  17  mfcc_std             2452 non-null   float64
#  18  mfcc_min             2452 non-null   float64
#  19  mfcc_max             2452 non-null   float64
#  20  sc_mean              2452 non-null   float64
#  21  sc_std               2452 non-null   float64
#  22  sc_min               2452 non-null   float64
#  23  sc_max               2452 non-null   float64
#  24  sc_kur               2452 non-null   float64
#  25  sc_skew              2452 non-null   float64
#  26  stft_mean            2452 non-null   float64
#  27  stft_std             2452 non-null   float64
#  28  stft_min             2452 non-null   float64
#  29  stft_max             2452 non-null   float64
#  30  stft_kur             2452 non-null   float64
#  31  stft_skew            2452 non-null   float64
#  32  mean                 2452 non-null   float64
#  33  std                  2452 non-null   float64
#  34  min                  2452 non-null   float64
#  35  max                  2452 non-null   float64
#  36  kur                  2452 non-null   float64
#  37  skew                 2452 non-null   float64
# dtypes: float64(25), int64(6), object(7)
# memory usage: 728.1+ KB

# %%
#Showing % null values for features
df.isna().sum() / len(df)
# Out:
# modality               0.000000
# vocal_channel          0.079935
# emotion                0.000000
# emotional_intensity    0.000000
# statement              0.000000
# repetition             0.000000
# actor                  0.459217
# sex                    0.000000
# channels               0.000000
# sample_width           0.000000
# frame_rate             0.000000
# frame_width            0.000000
# length_ms              0.000000
# frame_count            0.000000
# intensity              0.332790
# zero_crossings_sum     0.000000
# mfcc_mean              0.000000
# mfcc_std               0.000000
# mfcc_min               0.000000
# mfcc_max               0.000000
# sc_mean                0.000000
# sc_std                 0.000000
# sc_min                 0.000000
# sc_max                 0.000000
# sc_kur                 0.000000
# sc_skew                0.000000
# stft_mean              0.000000
# stft_std               0.000000
# stft_min               0.000000
# stft_max               0.000000
# stft_kur               0.000000
# stft_skew              0.000000
# mean                   0.000000
# std                    0.000000
# min                    0.000000
# max                    0.000000
# kur                    0.000000
# skew                   0.000000
# dtype: float64

# %%
#Unique values for each feature
df.nunique()
# Out:
# modality                  1
# vocal_channel             2
# emotion                   8
# emotional_intensity       2
# statement                 2
# repetition                2
# actor                    24
# sex                       2
# channels                  2
# sample_width              1
# frame_rate                1
# frame_width               2
# length_ms                95
# frame_count             158
# intensity               989
# zero_crossings_sum     2176
# mfcc_mean              2451
# mfcc_std               2449
# mfcc_min               2451
# mfcc_max               2449
# sc_mean                2451
# sc_std                 2451
# sc_min                 1431
# sc_max                 2423
# sc_kur                 2451
# sc_skew                2451
# stft_mean              2451
# stft_std               2451
# stft_min               1431
# stft_max                  1
# stft_kur               2451
# stft_skew              2451
# mean                   2450
# std                    2451
# min                    2148
# max                    2166
# kur                    2451
# skew                   2451
# dtype: int64

# %%
#Dropping the features as explained before
df = df.drop(['modality','statement','sample_width','frame_rate', 'stft_max', 'actor','frame_count'], axis=1)

# %% [markdown]
# # Assessing data quality (missing values, outliers)

# %% [markdown]
# As mentioned above, two different approaches were used to fill in the missing values of the two columns with missing values. For the vocal_channel attribute, a function was created to fill in the missing values with randomly selected values from the columns, but respecting the proportion in which they appear within the dataset (song= 0.41 and speech=0.59).
# In the case of intensity, on the other hand, the missing value was predicted through the application of a linear regression, using as training set the variables "zero_crossings_sum," "mfcc_mean," two variables highly correlated with intensity. This technique was chosen after trying to fill in the missing values through the variable's mode, median and mean values. In fact, the distributions obtained by using these methods did not respect the initial distribution of the variable, changing it significantly.

# %%
#We have filled vocal following the distribution of the data set 41% song and 59% speech
def fill_vocal(row):
    if pd.isnull(row['vocal_channel']):
        return np.random.choice(['song', 'speech'], p=[0.41,0.59])
    else:
        return row['vocal_channel']
df['vocal_channel'] = df.apply(fill_vocal, axis=1)
df['vocal_channel'].value_counts().plot(kind='bar', title='speech and song count')
plt.show()

# %% [markdown]
# ### Filling Intensity building a regression model

# %%
not_na_mask = ~df["intensity"].isna().values
na_mask = df["intensity"].isna().values
not_na_idxs = np.argwhere(not_na_mask).ravel()
na_idxs = np.argwhere(na_mask).ravel()
not_na_idxs
# Out:
# array([   0,    2,    3, ..., 2448, 2450, 2451])

# %%
#         -37.85920009, -42.95033139, -32.96501085, -33.82336579,
#         -31.15868476, -37.97227333, -39.51855122, -27.40827358,
#         -44.77407139, -34.63001722, -33.28194608, -48.62941984,
#         -32.89740218, -48.47362094, -32.80826198, -32.88124428,
#         -49.58345934, -36.04434142, -32.77596898, -25.36792169,
#         -27.53960468, -43.23471076, -51.8402383 , -31.50093809,
#         -31.33220043, -41.1865225 , -35.71556414, -49.97815537,
#         -41.36228779, -49.2705312 , -41.79324107, -32.99553623,
#         -47.93814637, -31.58348242, -40.86433821, -44.98244575,
#         -48.44057667, -34.94885647, -38.8053076 , -31.37936443,
#         -18.88140136, -40.23176639, -37.96941468, -49.20614556,
#         -49.86723431, -40.90338127, -34.25600242, -39.39569483,
#         -34.31614327, -31.45461436, -39.17062305, -39.97179411,
#         -43.78858714, -34.95942439, -38.7504609 , -41.70919621,
#         -26.65775932, -25.39432599, -25.5416805 , -32.04361869,
#         -40.84349827, -39.27014087, -42.34056204, -44.60057144,
#         -31.57678233, -26.92229371, -41.74652003, -41.78197407,
#         -34.96069914, -43.08895895, -41.84433445, -34.17297922,
#         -39.88551182, -39.51644128, -42.13682706, -37.9193077 ]))

# %%
df['intensity'][na_idxs] = y_pred
# Out:
# /var/folders/js/82fxm5rj3154nbsny8gqb1jh0000gn/T/ipykernel_67446/2000266259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['intensity'][na_idxs] = y_pred

# %% [markdown]
# ### Correlation after filling every column

# %%
#Selected features for correlation
df_col = df[['length_ms', 'intensity', 'zero_crossings_sum', 'mfcc_mean', 'mfcc_std',
       'mfcc_min', 'mfcc_max', 'sc_mean', 'sc_std', 'sc_min', 'sc_max',
       'sc_kur', 'sc_skew', 'stft_kur', 'stft_skew', 'max', 'kur', 'skew']]

# %%
#Compute pairwise correlation of selected features
pd.options.display.max_columns = None
df_corr = df_col.corr(numeric_only=True)
styled_corr = df_corr.style.background_gradient(cmap='coolwarm').format(precision=2)
display(styled_corr)
# Out:
# <style type="text/css">
# #T_9154f_row0_col0, #T_9154f_row1_col1, #T_9154f_row2_col2, #T_9154f_row3_col3, #T_9154f_row4_col4, #T_9154f_row5_col5, #T_9154f_row6_col6, #T_9154f_row7_col7, #T_9154f_row8_col8, #T_9154f_row9_col9, #T_9154f_row10_col10, #T_9154f_row11_col11, #T_9154f_row12_col12, #T_9154f_row13_col13, #T_9154f_row14_col14, #T_9154f_row15_col15, #T_9154f_row16_col16, #T_9154f_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col1, #T_9154f_row1_col11 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_9154f_row0_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_9154f_row0_col3, #T_9154f_row4_col16 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_9154f_row0_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_9154f_row0_col5, #T_9154f_row15_col11 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_9154f_row0_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col7, #T_9154f_row2_col8, #T_9154f_row9_col17, #T_9154f_row10_col3, #T_9154f_row12_col10, #T_9154f_row15_col10, #T_9154f_row16_col14 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col8 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9154f_row0_col9, #T_9154f_row12_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_9154f_row0_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col11, #T_9154f_row2_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_9154f_row0_col12, #T_9154f_row1_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col13, #T_9154f_row5_col10, #T_9154f_row15_col6, #T_9154f_row15_col8 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col14, #T_9154f_row5_col3, #T_9154f_row12_col0 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_9154f_row0_col15, #T_9154f_row5_col0, #T_9154f_row16_col5, #T_9154f_row17_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_9154f_row0_col16, #T_9154f_row3_col10, #T_9154f_row4_col1, #T_9154f_row4_col2, #T_9154f_row4_col3, #T_9154f_row4_col5, #T_9154f_row4_col15, #T_9154f_row4_col17, #T_9154f_row5_col4, #T_9154f_row7_col0, #T_9154f_row7_col11, #T_9154f_row7_col12, #T_9154f_row7_col14, #T_9154f_row8_col9, #T_9154f_row8_col11, #T_9154f_row8_col13, #T_9154f_row11_col8, #T_9154f_row12_col7, #T_9154f_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9154f_row0_col17, #T_9154f_row7_col2, #T_9154f_row16_col13, #T_9154f_row17_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_9154f_row1_col0, #T_9154f_row9_col15, #T_9154f_row13_col11 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_9154f_row1_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_9154f_row1_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col5, #T_9154f_row5_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col7, #T_9154f_row9_col13 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_9154f_row1_col8, #T_9154f_row6_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col9, #T_9154f_row2_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_9154f_row1_col10, #T_9154f_row4_col11, #T_9154f_row9_col8, #T_9154f_row10_col13, #T_9154f_row11_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col12 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_9154f_row1_col13, #T_9154f_row10_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col14 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_9154f_row1_col15 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_9154f_row1_col16, #T_9154f_row2_col10, #T_9154f_row11_col16, #T_9154f_row12_col9, #T_9154f_row14_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9154f_row1_col17, #T_9154f_row15_col17 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_9154f_row2_col1, #T_9154f_row8_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_9154f_row2_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_9154f_row2_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_9154f_row2_col5, #T_9154f_row10_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_9154f_row2_col6, #T_9154f_row14_col16 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9154f_row2_col7, #T_9154f_row2_col17 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_9154f_row2_col11, #T_9154f_row15_col14, #T_9154f_row16_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_9154f_row2_col12, #T_9154f_row13_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_9154f_row2_col13 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_9154f_row2_col14, #T_9154f_row14_col5 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_9154f_row2_col15, #T_9154f_row5_col2, #T_9154f_row10_col7, #T_9154f_row12_col1, #T_9154f_row12_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_9154f_row2_col16, #T_9154f_row8_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_9154f_row3_col0, #T_9154f_row6_col9, #T_9154f_row9_col16, #T_9154f_row10_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_9154f_row3_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_9154f_row3_col2, #T_9154f_row7_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_9154f_row3_col4, #T_9154f_row7_col13, #T_9154f_row11_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_9154f_row3_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_9154f_row3_col6, #T_9154f_row13_col5, #T_9154f_row17_col8 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_9154f_row3_col7, #T_9154f_row5_col7, #T_9154f_row6_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_9154f_row3_col8, #T_9154f_row8_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_9154f_row3_col9 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_9154f_row3_col11, #T_9154f_row11_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_9154f_row3_col12, #T_9154f_row5_col14 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_9154f_row3_col13, #T_9154f_row15_col13 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_9154f_row3_col14, #T_9154f_row6_col10, #T_9154f_row10_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_9154f_row3_col15 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_9154f_row3_col16, #T_9154f_row9_col6, #T_9154f_row13_col14 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9154f_row3_col17, #T_9154f_row9_col0, #T_9154f_row11_col17 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_9154f_row4_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_9154f_row4_col6, #T_9154f_row9_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_9154f_row4_col7, #T_9154f_row17_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_9154f_row4_col8, #T_9154f_row8_col10 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_9154f_row4_col9, #T_9154f_row8_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_9154f_row4_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_9154f_row4_col12 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_9154f_row4_col13, #T_9154f_row9_col14, #T_9154f_row13_col8, #T_9154f_row13_col17 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_9154f_row4_col14, #T_9154f_row12_col6, #T_9154f_row14_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_9154f_row5_col6, #T_9154f_row15_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_9154f_row5_col8, #T_9154f_row14_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9154f_row5_col9, #T_9154f_row13_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_9154f_row5_col11 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_9154f_row5_col12, #T_9154f_row11_col14 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_9154f_row5_col13, #T_9154f_row6_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9154f_row5_col15 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_9154f_row5_col16, #T_

# %% [markdown]
# ## Finding Outliers with IQR method

# %% [markdown]
# To identify the outliers in the dataset, we decided starting our reflection from the 25% and 75% quantile. We added or subtracted from these (depending on whether it was upper or lower limit) the records that were within a distance of 1.5*IQR from the quantiles. This allowed us to select only the points that were actually most disturbing to the distribution, without limiting ourselves to the graphical outliers produced by the boxplots. In fact, using this graphical technique, we realized that the graphical outliers produced by the boxplots included many records that were not actually disturbing for the dataset.
# After defining what we consider to be outliers, we defined a function able of replacing these points with random values selected from the range of non-outliers of the variable under consideration.

# %%
#Selected colums
col = ['length_ms', 'intensity', 'zero_crossings_sum', 'mfcc_mean', 'mfcc_std',
       'mfcc_min', 'mfcc_max', 'sc_mean', 'sc_std', 'sc_min', 'sc_max',
       'sc_kur', 'sc_skew', 'stft_kur', 'stft_skew', 'max', 'kur', 'skew']

# %%
# Calculate Q1 and Q3 for each column
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)

# Calculate IQR for each column
IQR = Q3 - Q1

# Define lower and upper bounds for outlier detection
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify potential outliers
outliers = ((df[col] < lower_bound) | (df[col] > upper_bound))

# Count the number of potential outliers in each column
outlier_counts_before = outliers.sum()

# Display the count of potential outliers for each column
print(outlier_counts_before)
# Out:
# length_ms              11
# intensity              18
# zero_crossings_sum     52
# mfcc_mean              12
# mfcc_std                1
# mfcc_min               14
# mfcc_max                1
# sc_mean                 5
# sc_std                 30
# sc_min                  0
# sc_max                439
# sc_kur                152
# sc_skew                35
# stft_kur               69
# stft_skew              14
# max                   207
# kur                    85
# skew                   32
# dtype: int64

# %%
def prin_IQR(df, col):
# Calculate Q1 and Q3 for each column
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
# Calculate IQR for each column
    IQR = Q3 - Q1
# Define lower and upper bounds for outlier detection
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
# Identify potential outliers
    outliers = ((df[col] < lower_bound) | (df[col] > upper_bound))
# Count the number of potential outliers in each column
    outlier_counts = outliers.sum()
# Display the count of potential outliers for each column
    return outliers

# %%
#Definition of a function to eliminate outliers
def fill_outliers(df):
    for column in df.columns:
        if df[column].dtype == 'object':
            continue
        x = df[column]
        q1 = np.quantile(x, 0.25)
        q3 = np.quantile(x, 0.75)
        iqr = q3 - q1

        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr

        #Find index for outliers
        outliers_idx = (x < lower_bound) | (x > upper_bound)

        #Generating new random values based on the distribution of the x serie
        non_outliers = x[~outliers_idx]
        random_values = np.random.choice(non_outliers, sum(outliers_idx), replace=True)

        #Replace outliers with new values
        df.loc[outliers_idx, column] = random_values

    return df

# %%
fill_outliers(df)
# Out:
#      vocal_channel    emotion emotional_intensity repetition sex  channels  \
# 0           speech    fearful              normal        2nd   F         1
# 1           speech      angry              normal        1st   F         1
# 2           speech      happy              strong        2nd   F         1
# 3           speech  surprised              normal        1st   F         1
# 4             song      happy              strong        2nd   F         1
# ...            ...        ...                 ...        ...  ..       ...
# 2447        speech       calm              strong        1st   M         1
# 2448        speech       calm              normal        1st   M         1
# 2449          song        sad              strong        2nd   M         1
# 2450        speech  surprised              normal        1st   M         1
# 2451          song    neutral              normal        2nd   M         1
#
#       frame_width  length_ms  intensity  zero_crossings_sum  mfcc_mean  \
# 0               2       3737 -36.793432               16995 -33.485947
# 1               2       3904 -37.443235               13906 -29.502108
# 2               2       4671 -32.290737               18723 -30.532463
# 3               2       3637 -49.019839               11617 -36.059555
# 4               2       4404 -31.214503               15137 -31.405996
# ...           ...        ...        ...                 ...        ...
# 2447            2       4605 -42.136827                9871 -30.225578
# 2448            2       4171 -43.342901                8963 -31.160332
# 2449            2       5239 -37.919308                9765 -26.135280
# 2450            2       3737 -45.751265                9716 -28.242815
# 2451            2       3837 -40.018044                9427 -29.019236
#
#         mfcc_std   mfcc_min   mfcc_max      sc_mean       sc_std      sc_min  \
# 0     134.654860 -755.22345  171.69092  5792.550744  3328.055457    0.000000
# 1     130.485630 -713.98560  205.00770  5197.620555  4040.931570    0.000000
# 2     126.577110 -726.06036  165.45653  4830.743037  3332.131300    0.000000
# 3     159.725160 -842.94635  190.03609  5376.446478  4053.663073    0.000000
# 4     122.125824 -700.70276  161.13400  5146.012474  3442.724109    0.000000
# ...          ...        ...        ...          ...          ...         ...
# 2447  158.845500 -855.92420  208.18497  5886.647366  4114.260257    0.000000
# 2448  157.499700 -825.37410  220.79490  6602.742127  4191.727090    0.000000
# 2449  138.133210 -768.36536  235.53938  4654.156076  4231.511986    0.000000
# 2450  159.943400 -868.09576  219.84350  5524.736973  3596.031841  760.822547
# 2451  149.188950 -799.51010  219.52780  6082.676123  3963.725117    0.000000
#
#             sc_max    sc_kur   sc_skew  stft_mean  stft_std  stft_min  \
# 0     11096.082688 -1.120769  0.250940   0.415250  0.335533  0.000000
# 1     12000.290443 -1.531204  0.219582   0.417488  0.352380  0.000000
# 2     12007.751173 -1.130153  0.436699   0.379758  0.352270  0.000000
# 3     12048.223893 -1.497765  0.098802   0.407277  0.360552  0.000000
# 4     12025.582707 -1.167544  0.496066   0.415974  0.350655  0.000000
# ...            ...       ...       ...        ...       ...       ...
# 2447  12210.517144 -1.588861  0.184390   0.573838  0.304496  0.000000
# 2448  12064.561791 -1.614582 -0.113920   0.591010  0.306333  0.000000
# 2449  12207.179884 -1.337419  0.619346   0.467994  0.347843  0.000000
# 2450  11981.912464 -1.465594  0.206481   0.578854  0.308684  0.001565
# 2451  12199.773419 -1.501387  0.147574   0.554946  0.320787  0.000000
#
#       stft_kur  stft_skew          mean       std       min       max  \
# 0    -1.215025   0.403514  3.844916e-07  0.014482 -0.128632  0.138947
# 1    -1.384174   0.290905 -7.149491e-08  0.020417 -0.305725  0.263062
# 2    -1.242947   0.470350  2.429985e-06  0.024317 -0.137482  0.166351
# 3    -1.445318   0.274756  2.373929e-07  0.003561 -0.027374  0.024078
# 4    -1.366742   0.318926  8.454691e-07  0.027522 -0.192169  0.242676
# ...        ...        ...           ...       ...       ...       ...
# 2447 -1.075888  -0.310088  9.367040e-07  0.005260 -0.039856  0.052399
# 2448 -1.026071  -0.408018  4.614221e-07  0.006836 -0.064178  0.084045
# 2449 -1.473789   0.130310  1.711986e-07  0.015384 -0.093079  0.097260
# 2450 -1.277117  -0.242668 -4.400898e-06  0.005182 -0.057556  0.052002
# 2451 -1.257666  -0.237757  6.342640e-07  0.010001 -0.081512  0.103027
#
#             kur      skew
# 0      9.406061  0.273153
# 1     19.564187  0.292157
# 2      4.881241  0.302659
# 3     13.040259 -0.081014
# 4      7.485109  0.414872
# ...         ...       ...
# 2447   9.551363  0.759247
# 2448  22.517991  1.073633
# 2449   4.964319 -0.005821
# 2450  13.855588 -0.110966
# 2451  12.973181  1.032081
#
# [2452 rows x 31 columns]

# %%
# Calculate Q1 and Q3 for each column
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)

# Calculate IQR for each column
IQR = Q3 - Q1

# Define lower and upper bounds for outlier detection
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify potential outliers
outliers = ((df[col] < lower_bound) | (df[col] > upper_bound))

# Count the number of potential outliers in each column
outlier_counts_after = outliers.sum()

# Display the count of potential outliers for each column
print(outlier_counts_after)
# Out:
# length_ms               0
# intensity               7
# zero_crossings_sum      6
# mfcc_mean               0
# mfcc_std                0
# mfcc_min                2
# mfcc_max                0
# sc_mean                 0
# sc_std                  8
# sc_min                  0
# sc_max                356
# sc_kur                 64
# sc_skew                 1
# stft_kur               16
# stft_skew               1
# max                    88
# kur                    13
# skew                    4
# dtype: int64

# %% [markdown]
# We have succesfully removed the amount of outliers we express below:

# %%
outlier_counts_before - outlier_counts_after
# Out:
# length_ms              11
# intensity              11
# zero_crossings_sum     46
# mfcc_mean              12
# mfcc_std                1
# mfcc_min               12
# mfcc_max                1
# sc_mean                 5
# sc_std                 22
# sc_min                  0
# sc_max                 83
# sc_kur                 88
# sc_skew                34
# stft_kur               53
# stft_skew              13
# max                   119
# kur                    72
# skew                   28
# dtype: int64

# %% [markdown]
# # Variables transformations

# %% [markdown]
# We will replace all categorical variables using the binning technique to proceed later with analisys over them

# %%
df['sex'] = df['sex'].map({'M': 0, 'F': 1})
df['vocal_channel'] = df['vocal_channel'].map({'speech': 0, 'song': 1})
df['emotional_intensity'] = df['emotional_intensity'].map({'normal': 0, 'strong': 1})
df['repetition'] = df['repetition'].map({'1st': 1, '2nd': 2})
pd.get_dummies(df['emotion']).astype(int)

#Adding the transformed variables to dataframe
df = pd.concat([df, pd.get_dummies(df['emotion']).astype(int)], axis=1)

# %%
# Drop columns with std_dev < 0.1 except for the 'emotion' column
categorical_column = 'emotion'
std_dev = df.drop([categorical_column], axis=1).std()
columns_to_drop = std_dev[std_dev < 0.1].index.difference([categorical_column])
df = df.drop(columns=columns_to_drop)
df
# Out:
#       vocal_channel    emotion  emotional_intensity  repetition  sex  \
# 0                 0    fearful                    0           2    1
# 1                 0      angry                    0           1    1
# 2                 0      happy                    1           2    1
# 3                 0  surprised                    0           1    1
# 4                 1      happy                    1           2    1
# ...             ...        ...                  ...         ...  ...
# 2447              0       calm                    1           1    0
# 2448              0       calm                    0           1    0
# 2449              1        sad                    1           2    0
# 2450              0  surprised                    0           1    0
# 2451              1    neutral                    0           2    0
#
#       length_ms  intensity  zero_crossings_sum  mfcc_mean    mfcc_std  \
# 0          3737 -36.793432               16995 -33.485947  134.654860
# 1          3904 -37.443235               13906 -29.502108  130.485630
# 2          4671 -32.290737               18723 -30.532463  126.577110
# 3          3637 -49.019839               11617 -36.059555  159.725160
# 4          4404 -31.214503               15137 -31.405996  122.125824
# ...         ...        ...                 ...        ...         ...
# 2447       4605 -42.136827                9871 -30.225578  158.845500
# 2448       4171 -43.342901                8963 -31.160332  157.499700
# 2449       5239 -37.919308                9765 -26.135280  138.133210
# 2450       3737 -45.751265                9716 -28.242815  159.943400
# 2451       3837 -40.018044                9427 -29.019236  149.188950
#
#        mfcc_min   mfcc_max      sc_mean       sc_std      sc_min  \
# 0    -755.22345  171.69092  5792.550744  3328.055457    0.000000
# 1    -713.98560  205.00770  5197.620555  4040.931570    0.000000
# 2    -726.06036  165.45653  4830.743037  3332.131300    0.000000
# 3    -842.94635  190.03609  5376.446478  4053.663073    0.000000
# 4    -700.70276  161.13400  5146.012474  3442.724109    0.000000
# ...         ...        ...          ...          ...         ...
# 2447 -855.92420  208.18497  5886.647366  4114.260257    0.000000
# 2448 -825.37410  220.79490  6602.742127  4191.727090    0.000000
# 2449 -768.36536  235.53938  4654.156076  4231.511986    0.000000
# 2450 -868.09576  219.84350  5524.736973  3596.031841  760.822547
# 2451 -799.51010  219.52780  6082.676123  3963.725117    0.000000
#
#             sc_max    sc_kur   sc_skew  stft_kur  stft_skew       max  \
# 0     11096.082688 -1.120769  0.250940 -1.215025   0.403514  0.138947
# 1     12000.290443 -1.531204  0.219582 -1.384174   0.290905  0.263062
# 2     12007.751173 -1.130153  0.436699 -1.242947   0.470350  0.166351
# 3     12048.223893 -1.497765  0.098802 -1.445318   0.274756  0.024078
# 4     12025.582707 -1.167544  0.496066 -1.366742   0.318926  0.242676
# ...            ...       ...       ...       ...        ...       ...
# 2447  12210.517144 -1.588861  0.184390 -1.075888  -0.310088  0.052399
# 2448  12064.561791 -1.614582 -0.113920 -1.026071  -0.408018  0.084045
# 2449  12207.179884 -1.337419  0.619346 -1.473789   0.130310  0.097260
# 2450  11981.912464 -1.465594  0.206481 -1.277117  -0.242668  0.052002
# 2451  12199.773419 -1.501387  0.147574 -1.257666  -0.237757  0.103027
#
#             kur      skew  angry  calm  disgust  fearful  happy  neutral  sad  \
# 0      9.406061  0.273153      0     0        0        1      0        0    0
# 1     19.564187  0.292157      1     0        0        0      0        0    0
# 2      4.881241  0.302659      0     0        0        0      1        0    0
# 3     13.040259 -0.081014      0     0        0        0      0        0    0
# 4      7.485109  0.414872      0     0        0        0      1        0    0
# ...         ...       ...    ...   ...      ...      ...    ...      ...  ...
# 2447   9.551363  0.759247      0     1        0        0      0        0    0
# 2448  22.517991  1.073633      0     1        0        0      0        0    0
# 2449   4.964319 -0.005821      0     0        0        0      0        0    1
# 2450  13.855588 -0.110966      0     0        0        0      0        0    0
# 2451  12.973181  1.032081      0     0        0        0      0        1    0
#
#       surprised
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 2447          0
# 2448          0
# 2449          0
# 2450          1
# 2451          0
#
# [2452 rows x 31 columns]

# %%
pd.options.display.max_columns = None
display(df)
# Out:
#       vocal_channel    emotion  emotional_intensity  repetition  sex  \
# 0                 0    fearful                    0           2    1
# 1                 0      angry                    0           1    1
# 2                 0      happy                    1           2    1
# 3                 0  surprised                    0           1    1
# 4                 1      happy                    1           2    1
# ...             ...        ...                  ...         ...  ...
# 2447              0       calm                    1           1    0
# 2448              0       calm                    0           1    0
# 2449              1        sad                    1           2    0
# 2450              0  surprised                    0           1    0
# 2451              1    neutral                    0           2    0
#
#       length_ms  intensity  zero_crossings_sum  mfcc_mean    mfcc_std  \
# 0          3737 -36.793432               16995 -33.485947  134.654860
# 1          3904 -37.443235               13906 -29.502108  130.485630
# 2          4671 -32.290737               18723 -30.532463  126.577110
# 3          3637 -49.019839               11617 -36.059555  159.725160
# 4          4404 -31.214503               15137 -31.405996  122.125824
# ...         ...        ...                 ...        ...         ...
# 2447       4605 -42.136827                9871 -30.225578  158.845500
# 2448       4171 -43.342901                8963 -31.160332  157.499700
# 2449       5239 -37.919308                9765 -26.135280  138.133210
# 2450       3737 -45.751265                9716 -28.242815  159.943400
# 2451       3837 -40.018044                9427 -29.019236  149.188950
#
#        mfcc_min   mfcc_max      sc_mean       sc_std      sc_min  \
# 0    -755.22345  171.69092  5792.550744  3328.055457    0.000000
# 1    -713.98560  205.00770  5197.620555  4040.931570    0.000000
# 2    -726.06036  165.45653  4830.743037  3332.131300    0.000000
# 3    -842.94635  190.03609  5376.446478  4053.663073    0.000000
# 4    -700.70276  161.13400  5146.012474  3442.724109    0.000000
# ...         ...        ...          ...          ...         ...
# 2447 -855.92420  208.18497  5886.647366  4114.260257    0.000000
# 2448 -825.37410  220.79490  6602.742127  4191.727090    0.000000
# 2449 -768.36536  235.53938  4654.156076  4231.511986    0.000000
# 2450 -868.09576  219.84350  5524.736973  3596.031841  760.822547
# 2451 -799.51010  219.52780  6082.676123  3963.725117    0.000000
#
#             sc_max    sc_kur   sc_skew  stft_kur  stft_skew       max  \
# 0     11096.082688 -1.120769  0.250940 -1.215025   0.403514  0.138947
# 1     12000.290443 -1.531204  0.219582 -1.384174   0.290905  0.263062
# 2     12007.751173 -1.130153  0.436699 -1.242947   0.470350  0.166351
# 3     12048.223893 -1.497765  0.098802 -1.445318   0.274756  0.024078
# 4     12025.582707 -1.167544  0.496066 -1.366742   0.318926  0.242676
# ...            ...       ...       ...       ...        ...       ...
# 2447  12210.517144 -1.588861  0.184390 -1.075888  -0.310088  0.052399
# 2448  12064.561791 -1.614582 -0.113920 -1.026071  -0.408018  0.084045
# 2449  12207.179884 -1.337419  0.619346 -1.473789   0.130310  0.097260
# 2450  11981.912464 -1.465594  0.206481 -1.277117  -0.242668  0.052002
# 2451  12199.773419 -1.501387  0.147574 -1.257666  -0.237757  0.103027
#
#             kur      skew  angry  calm  disgust  fearful  happy  neutral  sad  \
# 0      9.406061  0.273153      0     0        0        1      0        0    0
# 1     19.564187  0.292157      1     0        0        0      0        0    0
# 2      4.881241  0.302659      0     0        0        0      1        0    0
# 3     13.040259 -0.081014      0     0        0        0      0        0    0
# 4      7.485109  0.414872      0     0        0        0      1        0    0
# ...         ...       ...    ...   ...      ...      ...    ...      ...  ...
# 2447   9.551363  0.759247      0     1        0        0      0        0    0
# 2448  22.517991  1.073633      0     1        0        0      0        0    0
# 2449   4.964319 -0.005821      0     0        0        0      0        0    1
# 2450  13.855588 -0.110966      0     0        0        0      0        0    0
# 2451  12.973181  1.032081      0     0        0        0      0        1    0
#
#       surprised
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 2447          0
# 2448          0
# 2449          0
# 2450          1
# 2451          0
#
# [2452 rows x 31 columns]

# %%
#Saving the dataframe in pickle to use in clustering and classification
df.to_pickle("./dataunderstanding.pkl")
